# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/v3-preparedatakgat/__results__.html
# /kaggle/input/v3-preparedatakgat/__notebook__.ipynb
# /kaggle/input/v3-preparedatakgat/__output__.json
# /kaggle/input/v3-preparedatakgat/custom.css
# /kaggle/input/v3-preparedatakgat/kgat_data/val.txt
# /kaggle/input/v3-preparedatakgat/kgat_data/relation_list.txt
# /kaggle/input/v3-preparedatakgat/kgat_data/item_list.txt
# /kaggle/input/v3-preparedatakgat/kgat_data/user_list.txt
# /kaggle/input/v3-preparedatakgat/kgat_data/test.txt
# /kaggle/input/v3-preparedatakgat/kgat_data/kg_final.txt
# /kaggle/input/v3-preparedatakgat/kgat_data/train.txt
# /kaggle/input/v3-preparedatakgat/kgat_data/entity_list.txt
# /kaggle/input/preparedatakgat/__results__.html
# /kaggle/input/preparedatakgat/__notebook__.ipynb
# /kaggle/input/preparedatakgat/__output__.json
# /kaggle/input/preparedatakgat/custom.css
# /kaggle/input/preparedatakgat/kgat_data/relation_list.txt
# /kaggle/input/preparedatakgat/kgat_data/item_list.txt
# ...

# %%
i=0
path = ["/kaggle/input/preparedatakgat",
        "/kaggle/input/v2-preparedatakgat",
        "/kaggle/input/v3-preparedatakgat",
        "/kaggle/input/v4-preparedatakgat",
        "/kaggle/input/v5-preparedatakgat"
       ]

# %%
# !pip install gitpython
import git
# !rm -rf /kaggle/working/sample
# !rm -rf /kaggle/working/trained_model
git.Repo.clone_from('https://github.com/Briandy23/KGAT-pytorch.git', '/kaggle/working/sample')
# %cd /kaggle/working/
# Out:
# ...
# /kaggle/working

# %%
# !python /kaggle/working/sample/main_kgat.py \
                    --data_dir "/kaggle/input/v5-preparedatakgat" \
                    --data_name kgat_data \
                    --use_pretrain 0 \
                    --n_epoch 350 \
                    --cf_batch_size 1024 \
                    --kg_batch_size 2048 \
                    --test_batch_size 256 \
                    --cf_print_every 500 \
                    --kg_print_every 500 \
                    --stopping_steps 7 \
                    --evaluate_every 5 \
                    --Ks '[5, 10]'
# Out:
# All logs will be saved to trained_model/KGAT/kgat_data/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/log0.log
# 2025-06-14 15:13:52,151 - root - INFO - Namespace(seed=2019, data_name='kgat_data', data_dir='/kaggle/input/v5-preparedatakgat', use_pretrain=0, pretrain_embedding_dir='datasets/pretrain/', pretrain_model_path='trained_model/model.pth', cf_batch_size=1024, kg_batch_size=2048, test_batch_size=256, embed_dim=64, relation_dim=64, laplacian_type='random-walk', aggregation_type='bi-interaction', conv_dim_list='[64, 32, 16]', mess_dropout='[0.1, 0.1, 0.1]', kg_l2loss_lambda=1e-05, cf_l2loss_lambda=1e-05, lr=0.0001, n_epoch=350, stopping_steps=7, cf_print_every=500, kg_print_every=500, evaluate_every=5, Ks='[5, 10]', save_dir='trained_model/KGAT/kgat_data/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/')
# 2025-06-14 15:14:09,929 - root - INFO - n_users:           24068
# ...

# %%
# !python /kaggle/working/sample/predict_kgat.py --data_dir "/kaggle/input/preparedatakgat" \
#                     --data_name kgat_data \
#                     --use_pretrain 2 \
#                     --pretrain_model_path /kaggle/input/kgat_pretrained_ep50/pytorch/kgat_ep50_pre/1/model_epoch50.pth \
#                     --n_epoch 6 \
#                     --cf_batch_size 1024 \
#                     --kg_batch_size 2048 \
#                     --test_batch_size 256 \
#                     --cf_print_every 50 \
#                     --kg_print_every 50 \
#                     --evaluate_every 2 \
#                     --Ks '[1, 5, 10]'
